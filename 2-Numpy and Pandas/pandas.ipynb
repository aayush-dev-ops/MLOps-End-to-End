# %%
import pandas as pd

# %% [markdown]
# Series - 1D array like object but can hold any data type. It is similar to a column in a table.

# %%
#create series frm list
data =[1,2,3,4,5]
series = pd.Series(data)
print(type(series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#create series frmi doctionary
data = {'a':1, 'c':3, 'b':2}
series_dict= pd.Series(data)
# Out:
# <class 'pandas.core.series.Series'>

# %%
series_dict
# Out:
# a    1
# c    3
# b    2
# dtype: int64

# %% [markdown]
# giving custom labelling

# %%
#no. of index should be queal to no. of elements
data = [10,20,30]
index=['a','b','c']

pd.Series(data,index = index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# DATAFRAMES

# %%
#dataframes: 2 dimenensional : similar to table 

#crate a dataframe  from a dictionary of lists
data ={
    'Name':['aayush', 'golu', 'jaan'],
    'age':[1,2,3],
    'city':['Floria', 'NY', 'Chicago']
}
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  age     city
# 0  aayush    1   Floria
# 1    golu    2       NY
# 2    jaan    3  Chicago

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#in numpy (just example)
import numpy as np
np.array(df)
# Out:
# array([['aayush', 1, 'Floria'],
#        ['golu', 2, 'NY'],
#        ['jaan', 3, 'Chicago']], dtype=object)

# %% [markdown]
# Create a dfrae from a list of dictionalry

# %%
data = [
        {'Name':'aayush','age':'25', 'city':"florida"},
        {'Name':'golu','age':'24', 'city':"chicago"},
        {'Name':'jaan','age':'1', 'city':"Kolkata"}
]

# %%
dfm = pd.DataFrame(data)

# %%
print(dfm)
# Out:
#      Name age     city
# 0  aayush  25  florida
# 1    golu  24  chicago
# 2    jaan   1  Kolkata

# %% [markdown]
# READ ANY CSV FILE. HOW?

# %%
df = pd.read_csv('Meta-Glasses-Reviews.csv')
df.head()
# Out:
#          reviewID          name               date  verifiedPurchase  rating  \
# 0  R26GJW65W9X4OB         HebeZ      March 9, 2025              True     4.0
# 1  R1LPZH3QJAOVAI   Karla silva   December 4, 2025              True     5.0
# 2  R1ASIRA3BE7065    Trinison12  November 12, 2025              True     5.0
# 3  R1W8SXTGV55AUH  Randy Harris   December 7, 2025              True     4.0
# 4  R1UTS0OJVZF1A1       SpunkyD   October 12, 2025              True     3.0
#
#   helpful                                          title  \
# 0      12  Solid Smart Glasses with Room for Improvement
# 1     NaN            Excelentes  a mi esposo le encantan
# 2     NaN                                 Now you see me
# 3       8        Great smart shades, but need more power
# 4       5                             Nice video taking!
#
#                                               review  \
# 0  The Ray-Ban Meta Glasses in the classic Wayfar...
# ...

# %%
df.tail()   # from bottom
# Out:
#             reviewID             name                date  verifiedPurchase  \
# 9995  R11G1TPE8GOJN2             C.C.       July 23, 2025              True
# 9996  R26NJCL81JUD26  Norma rodriguez   December 25, 2025              True
# 9997  R26NJCL81JUD26  Norma rodriguez   December 25, 2025              True
# 9998  R2APVAY7XFP0P5         Dj-KokoG  September 17, 2024              True
# 9999  R10DOA6X6D3X6U      Colin Obeso   December 16, 2025              True
#
#       rating helpful                                              title  \
# 9995     4.0       2                    Sharp sunglasses with cool tech
# 9996     5.0     NaN  Todo funciona bien y cumple con todo lo que es...
# 9997     5.0     NaN  Todo funciona bien y cumple con todo lo que es...
# 9998     4.0      95                       I didn't know what to expect
# 9999     3.0     NaN                      Previously owned/refurbished?
#
#                                                  review  \
# ...
