# %% [markdown]
# for exmaple agar we do 5>1: this will return TRUE. but opeartor overloading k help se we can change what will be displayed.

# %%
1+1
# Out:
# 2

# %%
class Complex:
    def __init__(self,real,img):
        self.real = real
        self.img = img

    def __add__(self,other):
        return Complex(self.real+other.real,self.img+other.img)
    
    
    def __sub__(self,other):
        return Complex(self.real-other.real,self.img-other.img)   

    def __eq__(self, other):
        return self.real == other.real and  other.img==self.img
    
    def __repr__(self):
        return f"solution is {self.real}+({self.img})i"

a = Complex(5,5)
b = Complex(2,10)

print(a-b)
print(a+b)
# Out:
# solution is 3+(-5)i
# solution is 7+(15)i
