# %% [markdown]
# Iterators: advance pytih which helps in looping, helping access elements sequentially WITHOUT EXPOSING THE UNDERLYING STRUCTURE

# %%
my_list = [1,2,3,4,5]
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
type(my_list)
# Out:
# list

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Iteratot: how to ceate? we will use ITER keyword
iterator = iter(my_list)
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
'''
i cannot see the list. it uses lazy loading technique.
it will not give us any element unless and until we iterate thru that element.
for iteration for all the elemets we will use "next()"
print(next(iterator)) # rteurn the 1st element of that list, next and next lazy loading.
'''
print(iterator) 

try:
    print(next(iterator))
except StopIteration:
    print("hey, stop. there are no more elements.")
# Out:
# ...
# hey, stop. there are no more elements.
